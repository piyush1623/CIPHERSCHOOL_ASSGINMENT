# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("a.csv")

# %%
df.head()
# Out:
#    age  workclass  fnlwgt     education  educational-num      marital-status  \
# 0   25    Private  226802          11th                7       Never-married
# 1   38    Private   89814       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov  336951    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  160323  Some-college               10  Married-civ-spouse
# 4   18          ?  103497  Some-college               10       Never-married
#
#           occupation relationship   race  gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct    Own-child  Black    Male             0             0
# 1    Farming-fishing      Husband  White    Male             0             0
# 2    Protective-serv      Husband  White    Male             0             0
# 3  Machine-op-inspct      Husband  Black    Male          7688             0
# 4                  ?    Own-child  White  Female             0             0
#
#    hours-per-week native-country income
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  educational-num  capital-gain  \
# count  48842.000000  4.884200e+04     48842.000000  48842.000000
# mean      38.643585  1.896641e+05        10.078089   1079.067626
# std       13.710510  1.056040e+05         2.570973   7452.019058
# min       17.000000  1.228500e+04         1.000000      0.000000
# 25%       28.000000  1.175505e+05         9.000000      0.000000
# 50%       37.000000  1.781445e+05        10.000000      0.000000
# 75%       48.000000  2.376420e+05        12.000000      0.000000
# max       90.000000  1.490400e+06        16.000000  99999.000000
#
#        capital-loss  hours-per-week
# count  48842.000000    48842.000000
# mean      87.502314       40.422382
# std      403.004552       12.391444
# min        0.000000        1.000000
# 25%        0.000000       40.000000
# 50%        0.000000       40.000000
# 75%        0.000000       45.000000
# max     4356.000000       99.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48842 entries, 0 to 48841
# Data columns (total 15 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   age              48842 non-null  int64
#  1   workclass        48842 non-null  object
#  2   fnlwgt           48842 non-null  int64
#  3   education        48842 non-null  object
#  4   educational-num  48842 non-null  int64
#  5   marital-status   48842 non-null  object
#  6   occupation       48842 non-null  object
#  7   relationship     48842 non-null  object
#  8   race             48842 non-null  object
#  9   gender           48842 non-null  object
#  10  capital-gain     48842 non-null  int64
#  11  capital-loss     48842 non-null  int64
#  12  hours-per-week   48842 non-null  int64
#  13  native-country   48842 non-null  object
#  14  income           48842 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 5.6+ MB

# %%
df.shape
# Out:
# (48842, 15)

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
val=["?","-","nan"]
df=pd.read_csv("a.csv",na_values=val)

# %%
df.isnull().sum()
# Out:
# age                   0
# workclass          2799
# fnlwgt                0
# education             0
# educational-num       0
# marital-status        0
# occupation         2809
# relationship          0
# race                  0
# gender                0
# capital-gain          0
# capital-loss          0
# hours-per-week        0
# native-country      857
# income                0
# dtype: int64

# %%
df.dropna(how='any',axis=0,inplace=True)

# %%
df.isnull().sum()
# Out:
# age                0
# workclass          0
# fnlwgt             0
# education          0
# educational-num    0
# marital-status     0
# occupation         0
# relationship       0
# race               0
# gender             0
# capital-gain       0
# capital-loss       0
# hours-per-week     0
# native-country     0
# income             0
# dtype: int64

# %%
x = 1 - len(df.index)/48842
print("Percentage of rows that get loss:",round(100*x),"%")
# Out:
# Percentage of rows that get loss: 7 %

# %%
df.drop('fnlwgt',axis=1,inplace=True)

# %%
df.shape
# Out:
# (45222, 14)

# %%
df.head()
# Out:
#    age  workclass     education  educational-num      marital-status  \
# 0   25    Private          11th                7       Never-married
# 1   38    Private       HS-grad                9  Married-civ-spouse
# 2   28  Local-gov    Assoc-acdm               12  Married-civ-spouse
# 3   44    Private  Some-college               10  Married-civ-spouse
# 5   34    Private          10th                6       Never-married
#
#           occupation   relationship   race gender  capital-gain  capital-loss  \
# 0  Machine-op-inspct      Own-child  Black   Male             0             0
# 1    Farming-fishing        Husband  White   Male             0             0
# 2    Protective-serv        Husband  White   Male             0             0
# 3  Machine-op-inspct        Husband  Black   Male          7688             0
# 5      Other-service  Not-in-family  White   Male             0             0
#
#    hours-per-week native-country income
# 0              40  United-States  <=50K
# ...

# %%
df['log_age'] = np.log(df['age'])
df['log_age'].plot(kind='hist')

# %%
df['log_gain'] = np.sqrt(df['capital-gain'])
df['log_gain'].plot(kind='hist')

# %%
df['log_loss'] = np.sqrt(df['capital-loss'])
df['log_loss'].plot(kind='hist')

# %%
df['log_edu_num'] = np.exp(df['educational-num'])
df['log_edu_num'].plot(kind='hist')

# %%
df['log_house'] = np.sqrt(df['hours-per-week'])
df['log_house'].plot(kind='hist')

# %%
df['workclass'].value_counts()
# Out:
# Private             33307
# Self-emp-not-inc     3796
# Local-gov            3100
# State-gov            1946
# Self-emp-inc         1646
# Federal-gov          1406
# Without-pay            21
# Name: workclass, dtype: int64

# %%
df["workclass"].replace({"Self-emp-not-inc":"Self-emp-inc",
                         "Local-gov":"Gover","State-gov":"Gover","Federal-gov":"Gover"},inplace=True)

# %%
df['workclass'].value_counts()
# Out:
# Private         33307
# Gover            6452
# Self-emp-inc     5442
# Without-pay        21
# Name: workclass, dtype: int64

# %%
df['marital-status'].value_counts()
# Out:
# Married-civ-spouse       21055
# Never-married            14598
# Divorced                  6297
# Separated                 1411
# Widowed                   1277
# Married-spouse-absent      552
# Married-AF-spouse           32
# Name: marital-status, dtype: int64

# %%
df["marital-status"].replace({"Married-civ-spouse":"Married","Married-AF-spouse":"Married"},inplace=True)

# %%
df['marital-status'].value_counts()
# Out:
# Married                  21087
# Never-married            14598
# Divorced                  6297
# Separated                 1411
# Widowed                   1277
# Married-spouse-absent      552
# Name: marital-status, dtype: int64

# %%
df['education'].value_counts()
# Out:
# HS-grad         14783
# Some-college     9899
# Bachelors        7570
# Masters          2514
# Assoc-voc        1959
# 11th             1619
# Assoc-acdm       1507
# 10th             1223
# 7th-8th           823
# Prof-school       785
# 9th               676
# 12th              577
# Doctorate         544
# 5th-6th           449
# 1st-4th           222
# Preschool          72
# Name: education, dtype: int64

# %%
var= df['education'].value_counts()

# %%
df['education_count'] = df['education'].apply(lambda x: var[x])
df[['education_count']].head()
# Out:
#    education_count
# 0             1619
# 1            14783
# 2             1507
# 3             9899
# 5             1223

# %%
df.loc[df["education_count"]<1500,"education"]="other"

# %%
df["education"].value_counts()
# Out:
# HS-grad         14783
# Some-college     9899
# Bachelors        7570
# other            5371
# Masters          2514
# Assoc-voc        1959
# 11th             1619
# Assoc-acdm       1507
# Name: education, dtype: int64

# %%
var1=df["native-country"].value_counts()

# %%
df["country_count"]=df["native-country"].apply(lambda x: var1[x])
df["country_count"].head()
# Out:
# 0    41292
# 1    41292
# 2    41292
# 3    41292
# 5    41292
# Name: country_count, dtype: int64

# %%
df["native-country"].value_counts()
# Out:
# United-States                 41292
# Mexico                          903
# Philippines                     283
# Germany                         193
# Puerto-Rico                     175
# Canada                          163
# India                           147
# El-Salvador                     147
# Cuba                            133
# England                         119
# China                           113
# Jamaica                         103
# South                           101
# Italy                           100
# Dominican-Republic               97
# Japan                            89
# Guatemala                        86
# Vietnam                          83
# Columbia                         82
# Poland                           81
# Haiti                            69
# Portugal                         62
# Iran                             56
# Taiwan                           55
# Greece                           49
# Nicaragua                        48
# ...

# %%
df.loc[df["country_count"]<150,"native-country"]="other"

# %%
df.shape
# Out:
# (45222, 21)

# %%
df
# Out:
#        age     workclass     education  educational-num marital-status  \
# 0       25       Private          11th                7  Never-married
# 1       38       Private       HS-grad                9        Married
# 2       28         Gover    Assoc-acdm               12        Married
# 3       44       Private  Some-college               10        Married
# 5       34       Private         other                6  Never-married
# ...    ...           ...           ...              ...            ...
# 48837   27       Private    Assoc-acdm               12        Married
# 48838   40       Private       HS-grad                9        Married
# 48839   58       Private       HS-grad                9        Widowed
# 48840   22       Private       HS-grad                9  Never-married
# 48841   52  Self-emp-inc       HS-grad                9        Married
#
#               occupation   relationship   race  gender  capital-gain  ...  \
# ...

# %%
var2= df['education'].value_counts()

# %%
df['educ_count'] = df['education'].apply(lambda x: var2[x])

# %%
#combining classes to reduceunique categorical variable
df.loc[df["educ_count"]<1500,"education"]="other"

# %%
df.shape
# Out:
# (45222, 22)

# %%
df.shape
# Out:
# (45222, 22)

# %%
df
# Out:
#        age     workclass     education  educational-num marital-status  \
# 0       25       Private          11th                7  Never-married
# 1       38       Private       HS-grad                9        Married
# 2       28         Gover    Assoc-acdm               12        Married
# 3       44       Private  Some-college               10        Married
# 5       34       Private         other                6  Never-married
# ...    ...           ...           ...              ...            ...
# 48837   27       Private    Assoc-acdm               12        Married
# 48838   40       Private       HS-grad                9        Married
# 48839   58       Private       HS-grad                9        Widowed
# 48840   22       Private       HS-grad                9  Never-married
# 48841   52  Self-emp-inc       HS-grad                9        Married
#
#               occupation   relationship   race  gender  capital-gain  ...  \
# ...

# %%
df
# Out:
#        age     workclass     education  educational-num marital-status  \
# 0       25       Private          11th                7  Never-married
# 1       38       Private       HS-grad                9        Married
# 2       28         Gover    Assoc-acdm               12        Married
# 3       44       Private  Some-college               10        Married
# 5       34       Private         other                6  Never-married
# ...    ...           ...           ...              ...            ...
# 48837   27       Private    Assoc-acdm               12        Married
# 48838   40       Private       HS-grad                9        Married
# 48839   58       Private       HS-grad                9        Widowed
# 48840   22       Private       HS-grad                9  Never-married
# 48841   52  Self-emp-inc       HS-grad                9        Married
#
#               occupation   relationship   race  gender  capital-gain  ...  \
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df["income"]=le.fit_transform(df["income"])

# %%
x = df.drop('income',axis=1)
y = df['income']

# %%
df.drop(["education_count","country_count","age","educational-num","capital-gain","capital-loss","hours-per-week"],axis=1,inplace=True)

# %%
y
# Out:
# 0        0
# 1        0
# 2        1
# 3        1
# 5        0
#         ..
# 48837    0
# 48838    1
# 48839    0
# 48840    0
# 48841    1
# Name: income, Length: 45222, dtype: int32

# %%
x = pd.get_dummies(x)

# %%
x.shape
# Out:
# (45222, 65)

# %%
x.drop("educ_count",inplace=True,axis=1)

# %%
x
# Out:
#        age  educational-num  capital-gain  capital-loss  hours-per-week  \
# 0       25                7             0             0              40
# 1       38                9             0             0              50
# 2       28               12             0             0              40
# 3       44               10          7688             0              40
# 5       34                6             0             0              30
# ...    ...              ...           ...           ...             ...
# 48837   27               12             0             0              38
# 48838   40                9             0             0              40
# 48839   58                9             0             0              40
# 48840   22                9             0             0              20
# 48841   52                9         15024             0              40
#
#         log_age    log_gain  log_loss    log_edu_num  log_house  ...  \
# ...

# %%
col = x.columns

# %%
from sklearn import preprocessing

# %%
scalling = preprocessing.StandardScaler()
scaled=scalling.fit_transform(x)
scaled=pd.DataFrame(scaled,columns=col)

# %%
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y=train_test_split(scaled,y,stratify=y, test_size=0.25)

# %%
from sklearn.linear_model import LogisticRegression 
from sklearn.metrics import classification_report,accuracy_score

# %%
lr = LogisticRegression()
lr.fit(train_x,train_y)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred=lr.predict(train_x)

# %%
print(classification_report(pred,train_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.91     26958
#            1       0.62      0.75      0.68      6958
#
#     accuracy                           0.85     33916
#    macro avg       0.78      0.81      0.79     33916
# weighted avg       0.87      0.85      0.86     33916

# %%
pred2=lr.predict(test_x)

# %%
print(classification_report(pred2,test_y))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.88      0.90      9040
#            1       0.61      0.75      0.67      2266
#
#     accuracy                           0.85     11306
#    macro avg       0.77      0.81      0.79     11306
# weighted avg       0.87      0.85      0.86     11306

# %%
 from sklearn.feature_selection import RFE

# %%
rf = RFE(lr,64)

# %%
rfe = rf.fit(x,y)

# %%
rfe_df=pd.DataFrame({"col":train_x.columns,"include":rfe.support_,"rank":rfe.ranking_})

# %%
x_col=train_x.columns[rfe.support_]

# %%
x2 = x[x_col]

# %%
x2.shape
# Out:
# (45222, 64)

# %%
x_train_1,x_test_1,y_train_1,y_test_1=train_test_split(x2,y,random_state=101,stratify=y, test_size=0.3)

# %%
x_test_1.shape
# Out:
# (13567, 64)

# %%
x_train_1.shape
# Out:
# (31655, 64)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import f1_score,accuracy_score

# %%
lr_reg = LogisticRegression()
lr_reg.fit(x_train_1,y_train_1)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predicts=lr_reg.predict(x_train_1)

# %%
x_score = f1_score(predicts, y_train)
x_acc_score = accuracy_score(predicts,y_train)
print(x_score)
print(x_acc_score)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-77-805feeca261d> in <module>
# ----> 1 x_score = f1_score(predicts, y_train)
#       2 x_acc_score = accuracy_score(predicts,y_train)
#       3 print(x_score)
#       4 print(x_acc_score)
#
# NameError: name 'y_train' is not defined

# %%
predicts_1=lr_reg.predict(x_test_1)

# %%
test_score = f1_score(predicts_1, y_test_1)
test_acs_score = accuracy_score(predicts_1,y_test_1)
print(test_acs_score)
print(test_score)
# Out:
# 0.802535564236751
# 0.44129301355578726

# %%
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
feature=[]
acc_train=[]
acc_test=[]

for i in range(10,58,5):
    feature.append(i)
    rf = RFE(lr,i)
    rfe = rf.fit(x,y)
    x_col=train_x.columns[rfe.support_]
    x2 = x[x_col]
    x_train,x_test,y_train,y_test=train_test_split(x2,y,random_state=101,stratify=y, test_size=0.3)
    lr_reg.fit(x_train,y_train)
    predicts=lr_reg.predict(x_train)
    predicts_1=lr_reg.predict(x_test)
    x_acc_score = accuracy_score(predicts,y_train)
    acc_train.append(x_acc_score)
    test_acs_score = accuracy_score(predicts_1,y_test)
    acc_test.append(test_acs_score)
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# C:\Users\hp\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:940: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
l1 = [[acc_test],[feature]]

# %%
r_df = pd.DataFrame(data=[feature,acc_train,acc_test],index=["no_feature","ac_train","ac_test"]).T

# %%
r_df.head()
# Out:
#    no_feature  ac_train   ac_test
# 0        10.0  0.809761  0.808948
# 1        15.0  0.801580  0.801209
# 2        20.0  0.820976  0.817793
# 3        25.0  0.823061  0.820299
# 4        30.0  0.825525  0.823837

# %%
plt=sns.lineplot(x="no_feature",y="ac_test",data=r_df)

# %%
sns.lineplot(x="no_feature",y="ac_train",data=r_df)

# %%
from sklearn.decomposition import PCA

# %%
x_train2,x_test2,y_train2,y_test2=train_test_split(x2,y,random_state=101,stratify=y, test_size=0.3)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier()
knn.fit(x_train2,y_train2)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#                      weights='uniform')

# %%
prediction=knn.predict(x_test2)

# %%
print("classification report of test data:")
print(classification_report(prediction,y_test2))
# Out:
# classification report of test data:
#               precision    recall  f1-score   support
#
#            0       0.91      0.88      0.89     10493
#            1       0.63      0.69      0.66      3074
#
#     accuracy                           0.84     13567
#    macro avg       0.77      0.79      0.78     13567
# weighted avg       0.84      0.84      0.84     13567

# %%
from sklearn.svm import SVC

# %%
svm=SVC()

# %%
svm.fit(x_train2,y_train2)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
svmdict=svm.predict(x_test2)

# %%
print("classification report of train data:")
print(classification_report(svmdict,y_test2))
# Out:
# classification report of train data:
#               precision    recall  f1-score   support
#
#            0       0.97      0.80      0.88     12325
#            1       0.27      0.74      0.40      1242
#
#     accuracy                           0.80     13567
#    macro avg       0.62      0.77      0.64     13567
# weighted avg       0.90      0.80      0.83     13567

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
d_tree=DecisionTreeClassifier(max_depth=9)

# %%
d_tree.fit(x_train2,y_train2)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=9, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=None, splitter='best')

# %%
pre_tree=d_tree.predict(x_train2)
print("classification report of train data:")
print(classification_report(pre_tree,y_train2))
# Out:
# classification report of train data:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91     25578
#            1       0.60      0.78      0.68      6077
#
#     accuracy                           0.86     31655
#    macro avg       0.77      0.83      0.80     31655
# weighted avg       0.88      0.86      0.87     31655

# %%
pre2_tree=d_tree.predict(x_test2)
print("classification report of test data:")
print(classification_report(pre2_tree,y_test2))
# Out:
# classification report of test data:
#               precision    recall  f1-score   support
#
#            0       0.94      0.88      0.91     10949
#            1       0.59      0.76      0.67      2618
#
#     accuracy                           0.85     13567
#    macro avg       0.77      0.82      0.79     13567
# weighted avg       0.87      0.85      0.86     13567
